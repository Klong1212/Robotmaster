# %% [markdown]
# ### Robot Sensei ###

# %%
from robomaster import robot
import time
import threading
import copy


data_log = []
stop_event = threading.Event()
robot_graph = {
    'angle': 0,
    'tof': 0
}

def sub_data_handler(sub_info):
    # รับข้อมูลระยะทางจากเซ็นเซอร์ TOF โดยบวกระยะทาง 75 มิลลิเมตร
    robot_graph['tof'] = sub_info[0]+75

def sub_data_handler_angle(angle_info):
    # รับข้อมูลมุมจากกิมบอล โดยเราจะเอาแค่มุม หมุน (yaw)
    pitch_angle, yaw_angle, pitch_ground_angle, yaw_ground_angle = angle_info
    print(f"gimbal angle: pitch_angle:{pitch_angle}, yaw_angle:{yaw_angle}, pitch_ground_angle:{pitch_ground_angle}, yaw_ground_angle:{yaw_ground_angle}")
    robot_graph['angle'] = yaw_angle

def data_logger(log_interval):
    """
    ฟังก์ชันนี้จะทำงานใน background thread
    เพื่อบันทึกสถานะของหุ่นยนต์ลง list ตามช่วงเวลาที่กำหนด
    """
    while not stop_event.is_set():
        robot_graph['timestamp'] = pd.Timestamp.now()
        current_log = copy.deepcopy(robot_graph)
        data_log.append(current_log)
        time.sleep(log_interval)
    print("Data logger thread stopped.")

#สร้างออปเจ็คและกำหนดค่าเชื่อมต่อกับหุ่นยนต์

ep_robot = robot.Robot()
ep_robot.initialize(conn_type="ap")
ep_gimbal = ep_robot.gimbal
ep_sensor = ep_robot.sensor
#ปรับความถี่การเก็บข้อมูลของเซ็นเซอร์ TOF และกิมบอล
log_interval = 0.02
logger_thread = threading.Thread(target=data_logger, args=(log_interval,))

# หมุนกิมบอลไปที่ yaw=90 ด้วยความเร็ว 45 องศา/วินาที
ep_gimbal.moveto(pitch=0, yaw=90, pitch_speed=45, yaw_speed=45).wait_for_completed()
logger_thread.start()
# สมัครรับข้อมูลระยะทางจากเซ็นเซอร์ TOF
ep_sensor.sub_distance(freq=20, callback=sub_data_handler)
# สมัครรับข้อมูลมุมจากกิมบอล
ep_gimbal.sub_angle(freq=20, callback=sub_data_handler_angle)

# หมุนกิมบอลไปที่ yaw=-90 ด้วยความเร็ว 45 องศา/วินาที
ep_gimbal.moveto(pitch=0, yaw=-90, pitch_speed=45, yaw_speed=45).wait_for_completed()

# หยุด data logger
stop_event.set()
logger_thread.join()

ep_robot.close()
# บันทึกข้อมูลที่เก็บรวบรวมลงในไฟล์ CSV
df = pd.DataFrame(data_log)
# จัดลำดับคอลัมน์ให้สวยงาม
cols = [k for k in robot_graph.keys()]
df = df[cols]
df.to_csv("robot_full_data.csv", index=False)
print("Data saved to robot_full_data.csv successfully.")
# Out:
# gimbal angle: pitch_angle:-2.4, yaw_angle:90.2, pitch_ground_angle:0.0, yaw_ground_angle:98.4
# gimbal angle: pitch_angle:-2.4, yaw_angle:87.9, pitch_ground_angle:0.0, yaw_ground_angle:96.3
# gimbal angle: pitch_angle:-2.4, yaw_angle:84.7, pitch_ground_angle:0.0, yaw_ground_angle:93.7
# gimbal angle: pitch_angle:-2.4, yaw_angle:82.8, pitch_ground_angle:0.0, yaw_ground_angle:91.9
# gimbal angle: pitch_angle:-2.3, yaw_angle:80.2, pitch_ground_angle:0.0, yaw_ground_angle:89.2
# gimbal angle: pitch_angle:-2.3, yaw_angle:78.4, pitch_ground_angle:0.0, yaw_ground_angle:87.4
# gimbal angle: pitch_angle:-2.3, yaw_angle:75.8, pitch_ground_angle:0.0, yaw_ground_angle:84.7
# gimbal angle: pitch_angle:-2.3, yaw_angle:74.1, pitch_ground_angle:0.0, yaw_ground_angle:82.9
# gimbal angle: pitch_angle:-2.3, yaw_angle:71.4, pitch_ground_angle:0.0, yaw_ground_angle:80.2
# gimbal angle: pitch_angle:-2.3, yaw_angle:69.6, pitch_ground_angle:0.0, yaw_ground_angle:78.4
# gimbal angle: pitch_angle:-2.3, yaw_angle:66.7, pitch_ground_angle:0.0, yaw_ground_angle:75.7
# gimbal angle: pitch_angle:-2.3, yaw_angle:64.8, pitch_ground_angle:0.0, yaw_ground_angle:73.9
# gimbal angle: pitch_angle:-2.2, yaw_angle:61.8, pitch_ground_angle:0.0, yaw_ground_angle:71.2
# gimbal angle: pitch_angle:-2.2, yaw_angle:60.0, pitch_ground_angle:0.0, yaw_ground_angle:69.4
# gimbal angle: pitch_angle:-2.2, yaw_angle:57.4, pitch_ground_angle:0.0, yaw_ground_angle:66.7
# gimbal angle: pitch_angle:-2.2, yaw_angle:55.6, pitch_ground_angle:0.0, yaw_ground_angle:64.9
# gimbal angle: pitch_angle:-2.2, yaw_angle:53.0, pitch_ground_angle:0.0, yaw_ground_angle:62.2
# gimbal angle: pitch_angle:-2.1, yaw_angle:50.4, pitch_ground_angle:0.0, yaw_ground_angle:59.5
# gimbal angle: pitch_angle:-2.1, yaw_angle:48.7, pitch_ground_angle:0.0, yaw_ground_angle:57.7
# gimbal angle: pitch_angle:-2.0, yaw_angle:46.1, pitch_ground_angle:0.0, yaw_ground_angle:55.0
# gimbal angle: pitch_angle:-2.0, yaw_angle:44.3, pitch_ground_angle:0.0, yaw_ground_angle:53.2
# gimbal angle: pitch_angle:-1.9, yaw_angle:41.6, pitch_ground_angle:0.0, yaw_ground_angle:50.5
# gimbal angle: pitch_angle:-1.9, yaw_angle:39.7, pitch_ground_angle:0.0, yaw_ground_angle:48.7
# gimbal angle: pitch_angle:-1.8, yaw_angle:37.1, pitch_ground_angle:0.0, yaw_ground_angle:46.0
# gimbal angle: pitch_angle:-1.8, yaw_angle:35.2, pitch_ground_angle:0.0, yaw_ground_angle:44.2
# gimbal angle: pitch_angle:-1.8, yaw_angle:32.4, pitch_ground_angle:0.0, yaw_ground_angle:41.5
# gimbal angle: pitch_angle:-1.7, yaw_angle:30.5, pitch_ground_angle:0.0, yaw_ground_angle:39.7
# gimbal angle: pitch_angle:-1.7, yaw_angle:27.9, pitch_ground_angle:0.0, yaw_ground_angle:37.0
# gimbal angle: pitch_angle:-1.6, yaw_angle:25.1, pitch_ground_angle:0.0, yaw_ground_angle:34.3
# gimbal angle: pitch_angle:-1.6, yaw_angle:23.3, pitch_ground_angle:0.0, yaw_ground_angle:32.5
# gimbal angle: pitch_angle:-1.5, yaw_angle:20.6, pitch_ground_angle:0.0, yaw_ground_angle:29.8
# gimbal angle: pitch_angle:-1.5, yaw_angle:18.0, pitch_ground_angle:0.0, yaw_ground_angle:27.1
# gimbal angle: pitch_angle:-1.4, yaw_angle:16.1, pitch_ground_angle:0.0, yaw_ground_angle:25.3
# gimbal angle: pitch_angle:-1.4, yaw_angle:13.5, pitch_ground_angle:0.0, yaw_ground_angle:22.6
# gimbal angle: pitch_angle:-1.3, yaw_angle:11.6, pitch_ground_angle:0.0, yaw_ground_angle:20.8
# gimbal angle: pitch_angle:-1.3, yaw_angle:8.7, pitch_ground_angle:0.0, yaw_ground_angle:18.1
# gimbal angle: pitch_angle:-1.2, yaw_angle:6.9, pitch_ground_angle:0.0, yaw_ground_angle:16.3
# gimbal angle: pitch_angle:-1.2, yaw_angle:4.3, pitch_ground_angle:0.0, yaw_ground_angle:13.6
# gimbal angle: pitch_angle:-1.1, yaw_angle:2.5, pitch_ground_angle:0.0, yaw_ground_angle:11.8
# gimbal angle: pitch_angle:-1.1, yaw_angle:0.0, pitch_ground_angle:0.0, yaw_ground_angle:9.1
# gimbal angle: pitch_angle:-1.0, yaw_angle:-1.6, pitch_ground_angle:0.0, yaw_ground_angle:7.3
# gimbal angle: pitch_angle:-1.0, yaw_angle:-4.2, pitch_ground_angle:0.0, yaw_ground_angle:4.6
# gimbal angle: pitch_angle:-0.9, yaw_angle:-5.9, pitch_ground_angle:0.0, yaw_ground_angle:2.8
# gimbal angle: pitch_angle:-0.9, yaw_angle:-8.6, pitch_ground_angle:0.0, yaw_ground_angle:0.1
# gimbal angle: pitch_angle:-0.8, yaw_angle:-10.5, pitch_ground_angle:0.0, yaw_ground_angle:-1.6
# gimbal angle: pitch_angle:-0.8, yaw_angle:-13.5, pitch_ground_angle:0.0, yaw_ground_angle:-4.3
# gimbal angle: pitch_angle:-0.7, yaw_angle:-16.4, pitch_ground_angle:0.0, yaw_ground_angle:-7.0
# gimbal angle: pitch_angle:-0.6, yaw_angle:-18.2, pitch_ground_angle:0.0, yaw_ground_angle:-8.8
# gimbal angle: pitch_angle:-0.6, yaw_angle:-21.0, pitch_ground_angle:0.0, yaw_ground_angle:-11.5
# gimbal angle: pitch_angle:-0.6, yaw_angle:-23.6, pitch_ground_angle:0.0, yaw_ground_angle:-14.2
# gimbal angle: pitch_angle:-0.5, yaw_angle:-25.3, pitch_ground_angle:0.0, yaw_ground_angle:-16.0
# gimbal angle: pitch_angle:-0.5, yaw_angle:-27.8, pitch_ground_angle:0.0, yaw_ground_angle:-18.7
# gimbal angle: pitch_angle:-0.4, yaw_angle:-29.5, pitch_ground_angle:0.0, yaw_ground_angle:-20.5
# gimbal angle: pitch_angle:-0.4, yaw_angle:-32.2, pitch_ground_angle:0.0, yaw_ground_angle:-23.2
# gimbal angle: pitch_angle:-0.3, yaw_angle:-34.2, pitch_ground_angle:0.0, yaw_ground_angle:-25.0
# gimbal angle: pitch_angle:-0.3, yaw_angle:-37.1, pitch_ground_angle:0.0, yaw_ground_angle:-27.7
# gimbal angle: pitch_angle:-0.2, yaw_angle:-39.9, pitch_ground_angle:0.0, yaw_ground_angle:-30.4
# gimbal angle: pitch_angle:-0.2, yaw_angle:-41.7, pitch_ground_angle:0.0, yaw_ground_angle:-32.2
# gimbal angle: pitch_angle:-0.1, yaw_angle:-44.4, pitch_ground_angle:0.0, yaw_ground_angle:-34.9
# gimbal angle: pitch_angle:-0.1, yaw_angle:-46.0, pitch_ground_angle:0.0, yaw_ground_angle:-36.7
# gimbal angle: pitch_angle:0.0, yaw_angle:-48.5, pitch_ground_angle:0.0, yaw_ground_angle:-39.4
# gimbal angle: pitch_angle:0.0, yaw_angle:-50.2, pitch_ground_angle:0.0, yaw_ground_angle:-41.2
# gimbal angle: pitch_angle:0.0, yaw_angle:-52.7, pitch_ground_angle:0.0, yaw_ground_angle:-43.9
# gimbal angle: pitch_angle:0.0, yaw_angle:-54.5, pitch_ground_angle:0.0, yaw_ground_angle:-45.7
# gimbal angle: pitch_angle:0.0, yaw_angle:-57.4, pitch_ground_angle:0.0, yaw_ground_angle:-48.4
# gimbal angle: pitch_angle:0.0, yaw_angle:-59.4, pitch_ground_angle:0.0, yaw_ground_angle:-50.2
# gimbal angle: pitch_angle:0.1, yaw_angle:-62.2, pitch_ground_angle:0.0, yaw_ground_angle:-52.9
# gimbal angle: pitch_angle:0.1, yaw_angle:-64.2, pitch_ground_angle:0.0, yaw_ground_angle:-54.7
# gimbal angle: pitch_angle:0.1, yaw_angle:-67.0, pitch_ground_angle:0.0, yaw_ground_angle:-57.4
# gimbal angle: pitch_angle:0.1, yaw_angle:-69.5, pitch_ground_angle:0.0, yaw_ground_angle:-60.1
# gimbal angle: pitch_angle:0.1, yaw_angle:-71.3, pitch_ground_angle:0.0, yaw_ground_angle:-61.9
# gimbal angle: pitch_angle:0.2, yaw_angle:-73.9, pitch_ground_angle:0.0, yaw_ground_angle:-64.6
# gimbal angle: pitch_angle:0.2, yaw_angle:-75.7, pitch_ground_angle:0.0, yaw_ground_angle:-66.4
# gimbal angle: pitch_angle:0.2, yaw_angle:-78.2, pitch_ground_angle:0.0, yaw_ground_angle:-69.1
# gimbal angle: pitch_angle:0.2, yaw_angle:-81.0, pitch_ground_angle:0.0, yaw_ground_angle:-71.8
# gimbal angle: pitch_angle:0.2, yaw_angle:-83.9, pitch_ground_angle:0.0, yaw_ground_angle:-74.5
# gimbal angle: pitch_angle:0.2, yaw_angle:-85.7, pitch_ground_angle:0.0, yaw_ground_angle:-76.3
# gimbal angle: pitch_angle:0.3, yaw_angle:-88.5, pitch_ground_angle:0.0, yaw_ground_angle:-79.0
# gimbal angle: pitch_angle:0.3, yaw_angle:-90.1, pitch_ground_angle:0.0, yaw_ground_angle:-80.8
# Data logger thread stopped.
# gimbal angle: pitch_angle:0.3, yaw_angle:-91.0, pitch_ground_angle:0.0, yaw_ground_angle:-81.5
# Data saved to robot_full_data.csv successfully.

# %%
import pandas as pd
import matplotlib.pyplot as mp
# ดึงข้อมูลจากไฟล์ CSV ที่บันทึกไว้ และ คลีนข้อมูลเบื้องต้น
Raw_data = pd.read_csv("robotsensei_tof.csv")
Raw_data = Raw_data[Raw_data['tof'] <= 500]
Raw_data
# Out:
#      angle  tof                   timestamp
# 0      0.0    0  2025-07-15 11:18:02.578335
# 1      0.0    0  2025-07-15 11:18:02.601517
# 2      0.0    0  2025-07-15 11:18:02.633082
# 3     90.2  274  2025-07-15 11:18:02.664116
# 4     90.2  274  2025-07-15 11:18:02.695659
# ..     ...  ...                         ...
# 128  -83.9  298  2025-07-15 11:18:06.542517
# 129  -85.7  298  2025-07-15 11:18:06.572424
# 130  -88.5  296  2025-07-15 11:18:06.603288
# 131  -88.5  296  2025-07-15 11:18:06.633817
# 132  -90.1  293  2025-07-15 11:18:06.665065
#
# [128 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# แปลงมุมจากองศาเป็นเรเดียน และคำนวณระยะทางในแกน X และ Y
angles_rad = np.deg2rad(Raw_data['angle'])
distances = (Raw_data['tof'])+25


u = distances * np.cos(angles_rad)
v = distances * np.sin(angles_rad)
plt.figure(figsize=(12, 12))
plt.scatter(v, u, color='red')
plt.scatter(0, 0, color='b')

plt.grid()
plt.title('Camera Rotation Scatter plot')
plt.xlabel('X (mm)')
plt.ylabel('Y (mm)')
plt.show()
