# %%
import robomaster
from robomaster import robot, camera
import cv2
import keyboard
import matplotlib.pyplot as plt

# %%
if __name__ == '__main__':
    ep_robot = robot.Robot()
    ep_robot.initialize(conn_type="ap")

    ep_camera = ep_robot.camera

    ep_camera.start_video_stream(display=False,resolution='1080p')
    img = ep_camera.read_cv2_image(strategy="newest")
    cv2.imwrite(f"captured_image_3.jpg", img)

# %%
img = cv2.imread("captured_image_2.jpg")
image_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
h,s,v=cv2.split(image_hsv)
plt.imshow(h,cmap='hsv')
plt.imshow(h, cmap='hsv')
plt.title('Hue Channel')
plt.axis('off')
plt.show()

# %%
img_binary = ((h > 0) & (h < 10)) | ((h > 160) & (h < 180))
plt.imshow(img_binary, cmap='gra    y')
plt.title('Binary Image')
cv2.imwrite(f"image_binary.jpg", (img_binary.astype('uint8') * 255))
# Out:
# True
