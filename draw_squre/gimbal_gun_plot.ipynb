# %%
import pandas as pd
import matplotlib.pyplot as plt

# --- 1. อ่านและเตรียมข้อมูลจากไฟล์ CSV ---
try:
    # อ่านไฟล์ CSV และแปลงคอลัมน์ที่อาจเป็นค่าว่างให้เป็นตัวเลข (NaN)
    df = pd.read_csv("gimbal_mission_log.csv")
    numeric_cols = ['yaw_error', 'angle_pid_output', 'marker_error_x', 'marker_error_y', 
                    'vision_yaw_pid_output', 'vision_pitch_pid_output']
    for col in numeric_cols:
        df[col] = pd.to_numeric(df[col], errors='coerce')

    print("Successfully loaded gimbal_mission_log.csv")
except FileNotFoundError:
    print("Error: gimbal_mission_log.csv not found. Please run the robot controller script first.")
    exit()


# --- 2. สร้างกราฟ ---
fig, axs = plt.subplots(3, 1, figsize=(12, 16), sharex=True)
fig.suptitle('Gimbal PID Controller Performance Analysis', fontsize=16)

# --- กราฟที่ 1: มุม Yaw (Coarse vs Fine-tuning) ---
axs[0].plot(df['timestamp'], df['current_yaw'], label='Current Yaw', color='cyan', zorder=2)
axs[0].plot(df['timestamp'], df['target_yaw'], label='Target Yaw', color='red', linestyle='--', drawstyle='steps-post', zorder=1)
axs[0].set_ylabel('Angle (degrees)')
axs[0].set_title('Yaw Angle vs. Time')
axs[0].legend()
axs[0].grid(True)

# --- กราฟที่ 2: มุม Pitch (Fine-tuning) ---
# จะพล็อตเฉพาะช่วงที่มีการ fine-tuning ด้วย vision
df_fine_tune = df[df['stage'] == 'fine_tuning']
axs[1].plot(df['timestamp'], df['current_pitch'], label='Current Pitch', color='magenta', zorder=2)
axs[1].axhline(y=0, color='gray', linestyle=':', label='Pitch Center (0°)') # เส้นอ้างอิงที่ 0 องศา
axs[1].set_ylabel('Angle (degrees)')
axs[1].set_title('Pitch Angle vs. Time (Shows fine-tuning adjustments)')
axs[1].legend()
axs[1].grid(True)

# --- กราฟที่ 3: PID Output (ความเร็วที่สั่งงานมอเตอร์) ---
df_fine_tune = df[df['stage'] == 'fine_tuning']
axs[2].plot(df['timestamp'], df['current_yaw'], label='Current Yaw', color='magenta', zorder=2)
axs[2].axhline(y=0, color='gray', linestyle=':', label='Yaw Center (0°)') # เส้นอ้างอิงที่ 0 องศา
axs[2].set_ylabel('Angle (degrees)')
axs[2].set_title('Yaw Angle vs. Time (Shows fine-tuning adjustments)')
axs[2].legend()
axs[2].grid(True)


# --- 3. แสดงผลและบันทึกไฟล์ ---
plt.tight_layout(rect=[0, 0.03, 1, 0.96])
plt.savefig("gimbal_performance_plot.png")
print("\nGraph has been saved as gimbal_performance_plot.png")
plt.show()
# Out:
# Successfully loaded square_pid_log_with_xy.csv
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\asus\Documents\GitHub\Robotmaster\myrobot\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\asus\Documents\GitHub\Robotmaster\myrobot\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\asus\Documents\GitHub\Robotmaster\myrobot\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'current_pitch'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 32
#      29 axs[0].axis('equal') # ทำให้แกน X และ Y มีสเกลเท่ากันเพื่อให้เห็นรูปสี่เหลี่ยมจริงๆ
#      31 # --- กราฟที่ 2: มุม Yaw เทียบกับเวลา ---
# ---> 32 axs[1].plot(df_turn['timestamp'], df_turn['current_pitch'], label='Current Pitch', color='green', marker='.', linestyle='None', markersize=3)
#      33 axs[1].plot(df_turn['timestamp'], df_turn['target'], label='Target Pitch', color='red', linestyle='--', drawstyle='steps-post')
#      34 axs[1].set_xlabel('Time (s)')
#
# File c:\Users\asus\Documents\GitHub\Robotmaster\myrobot\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\asus\Documents\GitHub\Robotmaster\myrobot\lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'current_pitch'
